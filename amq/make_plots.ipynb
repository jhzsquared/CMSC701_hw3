# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
results = pd.read_csv('../results.csv')

# %%
bloom_results = results[results["method"]=="bloom"]

# %%
bloom_results["avg_size"] = results[results["method"]=="bloom"]['size_bits']/results[results["method"]=="bloom"]['num_items']
# Out:
# /tmp/ipykernel_25449/1519797834.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bloom_results["avg_size"] = results[results["method"]=="bloom"]['size_bits']/results[results["method"]=="bloom"]['num_items']

# %%
sns.barplot(results[results["method"]=="bloom"], x="fpr_2pow/b", y="actual_fpr", hue = "mix_perc")
# Out:
# <Axes: xlabel='fpr_2pow/b', ylabel='actual_fpr'>

# %%
sns.barplot(results[results["method"]=="bloom"], x="fpr_2pow/b", y="avg_time")
# Out:
# <Axes: xlabel='fpr_2pow/b', ylabel='avg_time'>

# %%
sns.barplot(results[results["method"]=="mpfh"], x="mix_perc", y="actual_fpr")
# Out:
# <Axes: xlabel='mix_perc', ylabel='actual_fpr'>

# %%
sns.barplot(results[results["method"]=="mpfh_fpt"], x="fpr_2pow/b", y="actual_fpr", hue = "mix_perc")
# Out:
# <Axes: xlabel='fpr_2pow/b', ylabel='actual_fpr'>

# %%
sns.boxplot(results, x="method", y="avg_time")
# Out:
# <Axes: xlabel='method', ylabel='avg_time'>

# %%
sns.scatterplot(results[results["method"]=="mpfh_fpt"], x="fpr_2pow/b", y="avg_time", hue = "mix_perc")
# Out:
# <Axes: xlabel='fpr_2pow/b', ylabel='avg_time'>

# %%
sns.scatterplot(results[results["method"]=="mpfh_fpt"], x="actual_fpr", y="avg_time", hue = "mix_perc")
# Out:
# <Axes: xlabel='actual_fpr', ylabel='avg_time'>

# %%
sns.scatterplot(results[results["method"]=="mpfh"], x="num_items", y="avg_time", hue = "mix_perc")
# Out:
# <Axes: xlabel='num_items', ylabel='avg_time'>

# %%
results[results["method"]=="mpfh_fpt"].groupby("num_items")["avg_time"].mean()
# Out:
# num_items
# 1000     0.176756
# 5000     0.177876
# 10000    0.198504
# 50000    0.174304
# Name: avg_time, dtype: float64

# %%
results[results["method"]=="mpfh"].groupby("num_items")["avg_time"].mean()
# Out:
# num_items
# 1000     0.076800
# 5000     0.056473
# 10000    0.077840
# 50000    0.067435
# Name: avg_time, dtype: float64

# %%
results[(results["method"]=="mpfh") &(results["mix_perc"]==.1)]["avg_time"].mean()
# Out:
# 0.06332399999999999

# %%
results[(results["method"]=="mpfh") &(results["mix_perc"]==.25)]["avg_time"].mean()
# Out:
# 0.07102449999999999

# %%
results[(results["method"]=="mpfh") &(results["mix_perc"]==.5)]["avg_time"].mean()
# Out:
# 0.0745625

# %%
results[(results["method"]=="mpfh") ]["avg_time"].mean()
# Out:
# 0.06963700000000002
